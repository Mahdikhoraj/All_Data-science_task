# %% [markdown]
# بخش اول
#
# Determine Business Objectives
#
# سوال 1
# مسئله اصلی کسب‌وکار را با زبان ساده توضیح دهید.
#
# مرکز قلب و عروق با افزایش تعداد بیماران مواجه شده است و درحال حاضر همه بیماران باید آزمایش قلب انجام بدن در حالی که این آزمایش زمان بر، پر هزینه و وابسته به تجهیزات هستند. بیماران با ریسک بالا و ریسک پایین هیچ تفکیکی ندارند و نتیجه برای همه بیماران یکسان است.
# __________________________________________________________________________________________________________
# سوال 2
# اگر این پروژه اجرا نشود چه مشکلاتی برای بیمارستان ایجاد خواهد شد؟
#
# عدم تفکیک بیماران پر ریسک با کم ریسک،زمان بر بودن،تکمیل شدن ظرفیت بخش ها و هزینه بالا برای بیماران و بیمارستان.
# __________________________________________________________________________________________________________
# سوال 3
# چه ذی‌نفعانی (Stakeholders) در این پروژه حضور دارند؟
# تمام افراد یا واحدهای سازمانی را فهرست کنید.
#
# مدیر بیمارستان، پزشکان یا متخصص قلب ، بیماران ، تیم اطلاعات داده بیمارستان
# __________________________________________________________________________________________________________
# سوال 4
# برای هر Stakeholder مشخص کنید:
#
# نیاز او چیست؟
# انتظار او از پروژه چیست؟
#
# مدیر بیمارستان: کاهش هزینه و استفاده بهینه از تجهیزات محدود
# انتظار: کاهش آزمایشات غیر ضروری و صرفه جویی مالی.
# پزشکان یا متخصص قلب: اعتماد به مدل طراحی شده و استفاده جهت بهبودی بیماران.
# انتظار: دقت و حساسیت بالای مدل در تشخیص.
# بیماران: کاهش زمان انتظار و رسیدگی به ان ها
# انتظار: کاهش انتظار و اولویت بندی بر اساس پر ریسک بودن.
# تیم اطلاعات: داده کافی و قابل استفاده در مدل.
# __________________________________________________________________________________________________________
# سوال 5
# هدف اصلی کسب‌وکار را در یک جمله بنویسید.
#
# تفکیک و شناسایی بیماران پر رسیک قلب قبل از انجام آزمایش های تخصصی بدون هزینه اضافی و فشار بر تجهیزات.
# __________________________________________________________________________________________________________
# سوال 6
# حداقل سه هدف فرعی برای این پروژه تعریف کنید.
#
# ۱ : ساخت مدلی که بیماران را بر اساس احتمال ابتلا به بیماری قلبی تفکیک کند.
# ۲: کاهش تعداد آزمایشات تخصصی روی بیماران کم ریسک‌.
# ۳: اولویت بندی زمان و تجهیزات بیماراستان برای بیمارانی که نیاز به آزمایش بیشتر دارند.
# __________________________________________________________________________________________________________
# سوال 7
# چه شاخص‌هایی نشان می‌دهد پروژه موفق بوده است؟
#
# (KPI)
# کاهش ازمایشات انجام شده روی بیماران کم‌ ریسک بدون ازدست رفتن بیماران با ریسک بالاتر.
# __________________________________________________________________________________________________________
# سوال 8
# حداقل پنج KPI برای این پروژه تعریف کنید.
#
# ۱ : درصد کاهش تعداد آزمایشات روی بیماران کم ریسک.
# ۲: کاهش زمان انتظار بیماران.
# ۳: شناسایی بیماران پر ریسک.
# ۴: میزان صرفه جویی در هزینه های بیمارستان.
# ۵: پذیرش پزشک و اعتماد جهت استفاده از مدل.
# __________________________________________________________________________________________________________
# سوال 9
# موفقیت این پروژه از دید مدیر بیمارستان چگونه اندازه‌گیری می‌شود؟
#
# هزینه های عملیاتی از جمله ازمایش کاهش پیدا کند ، فشار روی تجهیزات برداشته شود، ظرفیت بخش ها مدیریت شود.
# __________________________________________________________________________________________________________
# سوال 10
# موفقیت این پروژه از دید پزشکان چگونه اندازه‌گیری می‌شود؟
#
# مدل باید دقت بالایی داشته باشید تا جان بیمار را تحدید نکند و قابل اعتماد باشد تا پزشکان بتوانند از ان استفاده کنند.
# __________________________________________________________________________________________________________
# سوال 11
# اگر سیستم 90٪ دقت داشته باشد اما پزشکان به آن اعتماد نکنند آیا پروژه موفق است؟
#
# چرا؟
#
# پزشکان نقطه عطف هستند و اگر انها این مدل را تایید نکنند و به ان اعتماد نداشته باشند مدل با شکست مواجه می‌شود زیرا این پزشکان هستند باید از این مدل جهت انجام آزمایشات روی بیماران استفاده کنند.
# __________________________________________________________________________________________________________
# سوال 12
# مزایای مالی احتمالی پروژه را فهرست کنید.
#
# کاهش هزینه گرفتن آزمایشات غیر ضرور،کاهش هزینه در بستری شدن بیماران کم ریسک،  عدم گسترش دستگاه ها و تجهیزات بیمارستان.
# __________________________________________________________________________________________________________
# سوال 13
# مزایای عملیاتی احتمالی پروژه را فهرست کنید.
#
# کاهش معطلی بیماران در صف های آزمایش طولانی،توضیع ظرفیت های بیمارستان به درستی،کاهش کار پزشکان.
# __________________________________________________________________________________________________________
# سوال 14
# مزایای پزشکی احتمالی پروژه را فهرست کنید.
#
# تشخیص زود هنگام بیماران پر رسیک و درمان انها ، کاهش خطر از دست رفتن بیمار، کاهش آزمایشات غیر ضروری روی بیماران کم ریسک ،تمرکز روی بیماران پر ریسک در معرض خطر.
# __________________________________________________________________________________________________________
# سوال 15
# یک Business Objective Statement رسمی برای این پروژه بنویسید.
#
# به طور کلی و جامع هدف این پروژه توسعه هوشمند مبتنی بر داده کاوی است که با استفاده از داده اولیه از بیماران، احتمال ابتلا به بیماری قلبی را پیش از انجام آزمایشات تخصصی تر مورد برسی قرار می‌دهد تا بیماران با ریسک بالاتر که در معرض خطر هستند شناسایی و اقدامات لازم برای انها صورت بگیرد. در نتیجه در زمان و تجهیزات بیمارستان صرفه جویی می‌شود بدون اینکه در دقت شناسایی بیماران پر ریسک کاهش یابد.

# %% [markdown]
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
#
# بخش دوم
#
# Assess Situation
#
# سوال 16
# چه اطلاعاتی را قبل از شروع پروژه باید از بیمارستان دریافت کنید؟
#
# اهداف و انتظارات مدیریت از پروژه،ذی‌نفعان اصلی و نقش آن‌ها،فرایندهای بالینی و اداری مرتبط،
# نوع، حجم، فرمت و بازه زمانی داده‌های موجود در بیمارستان،مالکیت داده‌ها و سطح دسترسی به انها، محرمانگی و حریم خصوصی اطلاعات بیمار،مجوزهای قانونی، زیرساخت فنی: سرور، شبکه، فضای ذخیره‌سازی، نرم‌افزار،منابع انسانی، مالی و زمانی، محدودیت‌ها و ریسک‌های شناخته‌شده
# __________________________________________________________________________________________________________
# سوال 17
# حداقل 10 سوال که باید از مدیر بیمارستان بپرسید طراحی کنید.
#
# 1 هدف اصلی پروژه چیست و چه مشکلی را حل می‌کند؟
#
# 2. معیار موفقیت پروژه از نظر شما چیست؟
#
# 3. دامنه پروژه شامل کدام بخش‌ها یا گروه‌های بیماران می‌شود؟
#
# 4. ذی‌نفعان اصلی و تصمیم‌گیرندگان چه کسانی هستند؟
#
# 5. مالک داده‌ها کیست و دسترسی به داده‌ها چگونه امکان‌پذیر است؟
#
# 6. بودجه اختصاص‌یافته و محدودیت مالی پروژه چقدر است؟
#
# 7. زمان‌بندی مورد انتظار و مهلت‌های کلیدی چیست؟
#
# 8. مجوزهای قانونی و اخلاقی لازم تا چه حد دریافت شده است؟
#
# 9. تیم فنی و پشتیبانی بیمارستان چه توانایی‌هایی دارد؟
#
# 10. ریسک پذیری سازمان در برابر خطا چقدر است؟
#
# __________________________________________________________________________________________________________
#
# سوال 18
# حداقل 10 سوال که باید از پزشکان بپرسید طراحی کنید.
#
# 1. مسئله بالینی اصلی که می‌خواهید حل شود چیست؟
# 2. تصمیم‌گیری فعلی شما بر اساس چه داده‌ ای است؟
# 3. جامعه بیماران  چه ویژگی‌هایی دارد؟
# 4. معیارهای ورود و خروج بیماران به مطالعه چیست؟
# 5. چه داده‌هایی برای پاسخ به سوال بالینی ضروری است؟
# 6. تعریف دقیق خروجی بهینه چیست؟
# 7. در فرایند فعلی، چه نقاطی بیشترین خطا یا تأخیر را دارند؟
# 8. خروجی مدل باید چگونه و کجا به شما نمایش داده شود؟
# 9. چه سطحی از خطای مدل قابل قبول است؟ حساسیت مهم‌تر است یا دقت؟
# 10. داده های بیماران به چه شکل ثبت می‌شود؟
# 11. مدل باید جایگزین دکتر شود یا در کنار او باشد؟
# __________________________________________________________________________________________________________
#
# سوال 19
# محدودیت‌های احتمالی پروژه را فهرست کنید.
#
# محدودیت مالی، محدودیت نرم‌افزاری، محدودیت سخت افزاری، محدودیت زمانی ، محدودیت‌ها فنی ، محدودیت داده ای ، محدودیت قانونی و ...
# __________________________________________________________________________________________________________
#
# سوال 20
# محدودیت‌های مالی پروژه را تحلیل کنید.
#
# بودجه اولیه و بودجه جاری پروژه چقدر است؟
# هزینه سخت افزار،  نرم افزار،  سرور و..
# هزینه نیروی انسانی: تحلیل گر داده ، مهندس داده ، برنامه نویس و ..
# هزینه نگهداری و ویرایش و درصورت نیاز بروزرسانی مدل پس از استقرار.
# هزینه امنیت و حریم خصوصی
# __________________________________________________________________________________________________________
#
# سوال 21
# محدودیت‌های فنی پروژه را تحلیل کنید.
#
# داده های پراکنده در چند سیستم یا منبع مختلف.
# مشخص نبودن فرمت داده ها.
# داده های ناقص و گم شده.
# قدیمی بودن سیستم . و .. هستند.
# __________________________________________________________________________________________________________
#
# سوال 22
# محدودیت‌های قانونی و حریم خصوصی را تحلیل کنید.
#
# اطلاعات بیمار حساس است و باید حفظ شود و درصورت نیاز از اون کسب رضایت شود.
# حفظ اطلاعات پزشکی و عدم انتشار ان ها.
# ممنوعیت انتقال داده از یک منبع به منبع دیگر.
# مدت نگهداری و نحوه تعامل رو داده ها و...
# __________________________________________________________________________________________________________
#
# سوال 23
# مهم‌ترین ریسک‌های پروژه را شناسایی کنید.
#
# ریسک داده: ناکافی، ناقص یا بی‌کیفیت بودن داده‌ها
# · ریسک فنی: ناسازگاری نرم‌افزارها و سیستم‌ها
# · ریسک انسانی: نبود نیروی متخصص یا مقاومت کاربران
# · ریسک مالی: کمبود بودجه یا افزایش هزینه‌ها
#  ریسک مدیریتی: تغییر اهداف یا نیازهای سازمان
# ریسک قانونی: عدم رعایت حریم خصوصی یا مجوزها
#  ریسک اخلاقی: سوگیری مدل یا آسیب به بیمار
#  ریسک عملیاتی: اختلال در فرایند بالینی
#  ریسک امنیتی: نشت داده یا حمله سایبری
#  ریسک زمانی: تأخیر در تحویل پروژه
#  ریسک وابستگی به فروشنده
# ·ریسک عدم پذیرش مدل توسط پزشکان
# __________________________________________________________________________________________________________
#
# سوال 24
# برای هر ریسک:
#
# احتمال وقوع
# شدت اثر
# را تعیین کنید.
#
# .ناقص بودن داده، احتمال: زیاد،اثر:زیاد
# .نا سازگاری فنی سیستم ها، احتمال: متوسط،اثر: متوسط.
# .کمبود نیروی متخصص،احتمال: متوسط،اثر:زیاد
# .کمبود بودجه،احتمال: متوسط،اثر: زیاد
# .تغییر اهداف سازمان: احتمال،متوسط،  اثر: بسیار زیاد.
# __________________________________________________________________________________________________________
#
# سوال 25
# جدول Risk Assessment تهیه کنید.
#
# ریسک ها:
# .ناقص یا ناکافی بودن داده
# احتمال: زیاد
# اثر : زیاد
#
# .کیفیت پایین داده
# احتمال:زیاد
# اثر:زیاد
#
# .کمبود بودجه:
# احتمال: متوسط
# اثر: زیاد
#
# .تغییر نیاز ها و اهداف سازمان:
# احتمال: متوسط
# شدت: بسیار زیاد.
#
# .نبود نیروی متخصص
# احتمال: متوسط
# اثر: زیاد
#
# .ناسازگاری نرم افزار ها و سیستم ها:
# احتمال:زیاد
# اثر:متوسط
#
# .تاخیر در زمان بندی پروژه:
# احتمال:زیاد
# اثر: متوسط
#
# .نقص حریم خصوصی:
# احتمال: کم
# اثل: زیاد
# __________________________________________________________________________________________________________
#
# سوال 26
# چه داده‌هایی احتمالاً برای این پروژه مورد نیاز خواهند بود؟
#
# اطلاعات بالینی از جمله: سن،جنسیت،فشار خون،سطح کلسترول، قند خون،ضربان قلب،سابقه بیماری خانوادگی، بیماری قلبی،سیگار کشیدن و .. است.
# __________________________________________________________________________________________________________
#
# سوال 27
# چه داده‌هایی ممکن است جمع‌آوری آن‌ها دشوار باشد؟
#
# سوابق بیماران قدیمی که به صورت دست نویس و روی کاغذ اطلاعات هویتی و بالینی ان ها ثبت شده است که بسیار سخت برای جمع آوری است.
# __________________________________________________________________________________________________________
#
# سوال 28
# اگر داده‌های کافی وجود نداشته باشد چه راهکارهایی پیشنهاد می‌کنید؟
#
# همکاری با مراکز درمانی دیگر جهت تکمیل اطلاعات، شروع مدل سازی ساده تر که نیاز به داده کمتری دارند، جمع آوری داده جدید.
# __________________________________________________________________________________________________________
#
# سوال 29
# اگر داده‌ها دارای خطا باشند چه مشکلاتی ایجاد می‌شود؟
#
# عدم اطمینان به مدل ساخته شده توسط ما ،کاهش دقت و کارایی ،افزایش احتمال خطا و مهمتر از همه کاهش اعتماد پزشکان که مهمترین بخش کار و راس کار ما هستند.
# __________________________________________________________________________________________________________
#
# سوال 30
# یک SWOT Analysis برای پروژه تهیه کنید
#
# قوت ها : دسترسی به داده‌ها ، وجود متخصصان بیمارستان،  حمایت مدیریت و ...
# ضعف ها: کیفیت پایین داده ، سیستم های پراکنده،  کمبود بودجه , نبود متخصص، و محدویت دسترسی به داده ها.
# فرصت ها: بهبود وضعیت بیماران ،کاهش هزینه های درمانی،همکاری بیمارستان با جاهای دیگر و...
# تهدید ها: نقض حریم خصوصی،  تغیر قوانین، مقاومت کارکنان،کاهش بودجه، حملات سایبری و...

# %% [markdown]
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
#
# بخش سوم
#
# Determine Data Mining Goals
#
# سوال 31
# هدف داده‌کاوی این پروژه چیست؟
#
# هدف داده کاوی این است که مدلی ساخته شود که با استفاده از داده های بالینی بیماران احتمال ابتلا به بیماری های قلبی را پیش‌بینی کند و بیماران پر ریسک و کم ریسک را طبقه بندی کند.
# __________________________________________________________________________________________________________
# سوال 32
# تفاوت بین Business Goal و Data Mining Goal چیست؟
#
# در business goals  هدف ما این است که اهداف کسب و کار را مشخص کنیم و برای ان یک طرح مسئله ایجاد کنیم که درست و مفهوم منظور ما از این مدل را برساند که طبق میل ذی نفعان باشد.
# اما در data mining goals باید مسئله را از دید فنی و به زبان داده کاوی بیاوریم تا مدل مان را از روی ان پیش ببریم.
# __________________________________________________________________________________________________________
# سوال 33
# هدف داده‌کاوی پروژه را در یک جمله بنویسید.
#
# ساخت مدل طبقه بندی برای پیش‌بینی احتمال ابتلا به بیماری قلبی و تفکیک بیماران پر رسیک از کم ریسک قبل از آزمایش های تخصصی.
#
# _________________________________________________________________________________________________________
# سوال 34
# آیا این پروژه:
#
# Classification
# Regression
# Clustering
# Association Rule
#
# است؟
#
# دلایل خود را توضیح دهید.
#
# این پروژه یک طبقه بندی یا
# classification است زیرا ما باید یک دسته بیمار را از دسته بیماران دیگر شناسایی کنیم و پر رسیک ها را جدا کنیم.
# __________________________________________________________________________________________________________
#
# سوال 35
# اگر خروجی پروژه احتمال بیماری باشد، نوع مسئله چیست؟
#
# مسئله classification
#   است چون خروجی ما احتمال و در واقع نوعی پیش‌بینی حساب می‌شود.
# __________________________________________________________________________________________________________
#
# سوال 36
# اگر خروجی پروژه شدت بیماری باشد، نوع مسئله چیست؟
#
# اگر شدت به صورت درسته و گروهی باشد classification
# است اگر به صورت پیوسته و عددی باشد Regression است.
# __________________________________________________________________________________________________________
#
# سوال 37
# اگر خروجی پروژه گروه‌بندی بیماران باشد، نوع مسئله چیست؟
#
# از Clustering
# برای طبقه بندی و خوشه بندی بیماران استفاده می‌شود.
# __________________________________________________________________________________________________________
#
# سوال 38
# چه معیارهایی برای ارزیابی مدل اهمیت دارند؟
#
# از Recall, Precision, Accuracy استفاده می‌شود و همچنین باید معیار حساسیت بالایی داشته باشد برای از دست دادن بیماران پر ریسک.
# __________________________________________________________________________________________________________
#
# سوال 39
# Accuracy چیست و آیا برای این پروژه کافی است؟
#
# یعنی نسبت به پیش‌بینی های درست به کل پیش بینی ها است و برای این پروژه کامل نیست زیرا اگر داده یک شکل نباشد مدل ممکن است در پیش‌بینی دچار اشتباه شود و بیماران پر ریسک را تشخیص ندهد.
# __________________________________________________________________________________________________________
#
# سوال 40
# Precision چیست؟
#
# در Precision
#
#  توی این سناریو یعنی از بین بیمارانی که مدل پر ریسک تشخیص داده چند درصد واقعا پر ریسک هستند.
# __________________________________________________________________________________________________________
#
# سوال 41
# Recall چیست؟
#
# پ recall یعنی چند درصد از موارد واقعی و توسط مدل شناسایی و تحلیل شده اند در واقع از بین بیماران پر ریسک واقعی چند درصد توسط مدل شناسایی شده اند.
# __________________________________________________________________________________________________________
#
# سوال 42
# در این پروژه Precision مهم‌تر است یا Recall؟
#
# چرا؟
#
# در اینجا  Recall
#
#  مهم تر است زیرا  هدف اصلی ما شناسایی بیماران پر ریسک است و نباید هیچ بیمار پر ریسک از بین برود. اگر بیمار پر ریسک را کم ریسک تشخیص دهد بر روی بیمار آزمایشات اشتباهی صورت میگرد و ممکن است جانش در خطر بیوفتد.
# __________________________________________________________________________________________________________
#
# سوال 43
# هزینه False Positive چیست؟
#
# مفهوم false positive
#
#   یعنی مدل بیمار را پر ریسک تشخیص دهد ولی بیمار ما سالم باشد که هزینه ان اطلاف وقت و هزینه های انجام ازمایش است.
# __________________________________________________________________________________________________________
#
# سوال 44
# هزینه False Negative چیست؟
#
# مفهوم false negative
#
#  یعنی مدل بیمار را کم ریسک تشخیص دهد درصورتی که بیمار ما در وضعیت خطر ناک و پر ریسک است که در این جا جان بیمار ما در خطر است.
# __________________________________________________________________________________________________________
#
# سوال 45
# کدام خطا برای بیمارستان خطرناک‌تر است؟
#
# مفهوم false  negative
#
# خطرناک تر است زیرا اگر بیمار اشتباه تشخیص داده شود جان و سلامتی ان در خطر قرار می‌گیرد اما در false positive فقط زمان و هزینه بیمار طلف میشود.
# __________________________________________________________________________________________________________
#
# سوال 46
# موفقیت مدل را چگونه تعریف می‌کنید؟
#
# مدلی که recall بالایی داشته باشد یعنی بیماران پر ریسک را از کم ریسک تشخیص و شناسایی کند و
#
#  Precision قابل قبولی داشته باشد که در محیط اجرایی توسط پزشک قابل اعتماد و اجرا باشد.
# __________________________________________________________________________________________________________
#
# سوال 47
# حداقل سه معیار فنی برای موفقیت مدل تعریف کنید.
#
# ۱: دارای recall بالای ۹۰ درصد برای پر ریسک ها
#
#
# ۲: دارای FI_ score متعادل و قابل قبول باشد.
#
#
# ۳: ثبت صحت مدل روی داده ها.
# __________________________________________________________________________________________________________
#
# سوال 48
# حداقل سه معیار کسب‌وکاری برای موفقیت پروژه تعریف کنید.
#
# ۱ : کاهش هزینه بیمارستان
#
#
# ۲: کاهش تعداد آزمایشات غیر ضروری.
#
#
# ۳: کاهش زمان انتظار بیمار.
#
#
# ۴: افرایش رضایت پزشکان و بیماران.
#
#
# ۵: پذیرش سیستم توسط پزشکان جهت استفاده.
# __________________________________________________________________________________________________________
#
# سوال 49
# یک Data Mining Goal Statement رسمی بنویسید.
#
# هدف داده کاوی این پروژه ساخت یک مدل طبقه بندی دو دویی است که با استفاده از داده های بالینی بیماران ، احتمال ابتلا به بیماری قلبی را پیش‌بینی کند و بیماران پر ریسک را با recall بالا شناسایی کند تا قبل از انجام آزمایشات تخصصی اولویت بندی مناسبی برای بیماران صورت گیرد.
# __________________________________________________________________________________________________________
#
# سوال 50
# رابطه بین هدف داده‌کاوی و هدف کسب‌وکار را توضیح دهید.
#
# هدف کسب و کار در واقع با نوع مسئله است است از جمله چرا؟ و چه چیزی؟ مثال کاهش هزینه ، بهبود کيفيت درمان، شناسایی بیماران پر ریسک.
# هدف داده کاوی به چگونه صورت گرفتن آن است و به صورت فنی به ان می پردازد.
# ساخت مدلی که این شناسایی را به صورت خودکار و دقیق انجام دهد در واقع هدف داده کاوی استفاده از ابزاری برای رسیدن به هدف کسب و کار است.

# %% [markdown]
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
# بخش چهارم
#
# Produce Project Plan
#
# سوال 51
# تمام فازهای CRISP-DM را نام ببرید.
#
# ۱: درک کسب و کار business Understanding
# ۲: درک داده data understanding
# ۳: اماده سازی داده data preparation
# ۴: مدل سازی : Modeling
# ۵: ارزیابی evaluation
# ۶: استفرار deployment
# __________________________________________________________________________________________________________
#
# سوال 52
# برای هر فاز خروجی مورد انتظار را مشخص کنید.
#
# بخش business understanding: سند اهداف کسب‌وکار, ذی نفعان، ریسک ها
#
#
# بخش data understanding: گزارش شناخت داده‌ها و تحلیل کیفیت داده ها.
#
#
# بخش data preparation: دیتا ست تمیز ، زمان و اماده و مدل سازی کردن.
#
#
# بخش modeling: مدل آموزش دیده شده و ارزیابی شده
#
#
# بخش evaluation: گزارش نهایی ارزیابی فنی و کسب کار مدل.
#
#
# بخش deployment: سیستم قابل استفاده در محیط بالینی و مستندات.
# __________________________________________________________________________________________________________
#
# سوال 53
# یک Work Breakdown Structure (WBS) برای پروژه طراحی کنید.
#
# 1. مدیریت پروژه
#    · تعریف دامنه
#    · زمان‌بندی
#    · پایش پیشرفت
# 2. درک کسب‌وکار
#    · مصاحبه با ذی‌نفعان
#    · تعریف KPI
#    · تحلیل ریسک
# 3. درک داده
#    · شناسایی منابع داده
#    · بررسی کیفیت داده
# 4. آماده‌سازی داده
#    · پاک‌سازی
#    · یکپارچه‌سازی
#    · تبدیل و نرمال‌سازی
# 5. مدل‌سازی
#    · انتخاب الگوریتم
#    · آموزش مدل
#    · تنظیم پارامترها
# 6. ارزیابی
#    · ارزیابی فنی
#    · ارزیابی بالینی
#    · ارزیابی کسب‌وکاری
# 7. استقرار
#    · پیاده‌سازی
#    · آموزش کاربران
#    · پایش و نگهداری
# __________________________________________________________________________________________________________
#
# سوال 54
# چه تخصص‌هایی برای انجام پروژه مورد نیاز است؟
#
# متخصص داده‌کاوی یا Data Scientist
# مهندس داده یا Data Engineer
# متخصص قلب و عروق (به عنوان مشاور بالینی)
#  تحلیل‌گر کسب‌وکار
#  متخصص امنیت و حریم خصوصی
# مهندس نرم‌افزار
#  مدیر پروژه
# __________________________________________________________________________________________________________
#
# سوال 55
# اعضای تیم پروژه را تعریف کنید.
#
# مدیر پروژه
#
#
#  تحلیل‌گر کسب‌وکار
#
#
#  متخصص داده‌کاوی
#
#
#  مهندس داده
#
#
#  مشاور بالینی (پزشک قلب)
#
#
#  متخصص امنیت داده
#
#
#  مهندس استقرار
#
#
#  نماینده مدیریت بیمارستان
# __________________________________________________________________________________________________________
#
# سوال 56
# مسئولیت هر عضو تیم چیست؟
#
# عضو مسئولیت
#
#
# مدیر پروژه برنامه‌ریزی، هماهنگی، پایش پیشرفت و ارتباط با ذی‌نفعان
#
#
# تحلیل‌گر کسب‌وکار استخراج نیازها، مستندسازی
#
#
# متخصص داده‌کاوی طراحی و آموزش مدل، ارزیابی فنی
#
#
# مهندس داده جمع‌آوری، پاک‌سازی و آماده‌سازی داده
#
#
# مشاور بالینی اعتبارسنجی بالینی، تعریف متغیرهای مهم
#
#
# متخصص امنیت رعایت حریم خصوصی و امنیت داده
#
#
# مهندس استقرار پیاده‌سازی مدل در محیط بیمارستان
#
#
# نماینده مدیریت تأمین منابع و تصمیم‌گیری‌های کلان
# __________________________________________________________________________________________________________
#
# سوال 57
# منابع مورد نیاز پروژه را فهرست کنید.
#
# داده‌های بالینی بیماران
#
#
#  سخت‌افزار (سرور، GPU در صورت نیاز)
#
#
#  نرم‌افزار (Python، Jupyter، کتابخانه‌های ML)
#
#
#  نیروی انسانی متخصص
#
#
#  بودجه
#
#
#  زمان
#
#
#  مجوزهای قانونی و اخلاقی
#
#
#  زیرساخت شبکه و ذخیره‌سازی
# __________________________________________________________________________________________________________
#
# سوال 58
# ابزارهای نرم‌افزاری مورد نیاز پروژه را مشخص کنید.
#
# ابزار هایی Python (Pandas, NumPy, Scikit-learn,)
#
#
# ابزار Jupyter Notebook
#
#
# پایگاه داده sql
#
#
# کنترل نسخه با git
# ابزار های امنیتی
# __________________________________________________________________________________________________________
#
# سوال 59
# یک Timeline برای پروژه طراحی کنید.
#
# هفته ۱ تا ۲: Business Understanding
#
#
#  هفته ۳ تا ۴: Data Understanding
#
#
#  هفته ۵تا۷: Data Preparation
#
#
#  هفته ۸ تا ۱۰: Modeling
#
#
#  هفته ۱۱ تا ۱۲: Evaluation
#
#
#  هفته ۱۳ تا ۱۴: Deployment
#
#
#  هفته ۱۵: آموزش و تحویل
# __________________________________________________________________________________________________________
#
# سوال 60
# زمان مورد نیاز هر فاز را تخمین بزنید.
#
# Business Understanding ۲ هفته
#
#
# Data Understanding ۲ هفته
#
#
# Data Preparation ۳ هفته
#
#
# Modeling ۳ هفته
#
#
# Evaluation ۲ هفته
#
#
# Deployment ۲ هفته
# __________________________________________________________________________________________________________
#
# سوال 61
# وابستگی بین فازهای پروژه را مشخص کنید.
#
# بخش data understanding  وابسته به business understanding است.
#
#
# بخش data preparation وابسته به data understanding است .
#
#
# بخش Modeling وابسته به data preparation است.
#
#
# بخش evaluation وابسته به Modeling است.
#
#
# بخش deployment وابسته به evaluation است.
#
#
# در واقع هر مرحله وابسته به مرحله قبلی خودشه.
# __________________________________________________________________________________________________________
#
# سوال 62
# چه خروجی‌هایی باید به مدیر بیمارستان تحویل داده شود؟
#
# گزارش اهداف کسب‌وکار
#
#
# گزارش ریسک‌ها و محدودیت‌ها
#
#
# گزارش پیشرفت پروژه
#
#
# نتایج ارزیابی مدل
#
#
# گزارش  و مزایای مالی
#
#
# مستندات استقرار و آموزش مدل
# __________________________________________________________________________________________________________
#
# سوال 63
# چه خروجی‌هایی باید به پزشکان تحویل داده شود؟
#
# راهنمای استفاده
#
#
# گزارش دقت و محدودیت‌های مدل
#
#
# آموزش نحوه تفسیر خروجی مدل
#
#
# مستندات بالینی و اعتبارسنجی
# __________________________________________________________________________________________________________
#
# سوال 64
# معیار پذیرش پروژه توسط کارفرما چیست؟
#
# رسیدن به Recall بالای ۹۰٪ برای بیماران پرریسک
#
#
#  پذیرش سیستم توسط حداقل ۸۰٪ پزشکان
#
#
#  کاهش هزینه‌های آزمایش‌های غیرضروری
#
#
#  تحویل در زمان و بودجه تعیین‌شده
#
#
#  رعایت کامل حریم خصوصی و قوانین
# __________________________________________________________________________________________________________
#
# سوال 65
# حداقل 5 ریسک اجرایی پروژه را فهرست کنید.
#
# 1. ناقص بودن داده‌ها
# 2. کمبود بودجه
# 3. نبود نیروی متخصص
# 4. مقاومت پزشکان
# 5. تأخیر در زمان‌بندی
# 6. ناسازگاری سیستم‌ها
# 7. نقض حریم خصوصی
# __________________________________________________________________________________________________________
#
# سوال 66
# برای هر ریسک یک برنامه مقابله تعریف کنید.
#
#
# ریسک برنامه مقابله
#
#
# ناقص بودن داده‌ها پاک‌سازی، جمع‌آوری تکمیلی
#
#
# کمبود بودجه فازبندی، اولویت‌بندی، جذب بودجه تحقیقاتی
#
#
# نبود نیروی متخصص آموزش، استخدام، مشاور خارجی
#
#
# مقاومت پزشکان مشارکت در طراحی، آموزش، نمایش مزایا
#
#
# تأخیر در زمان‌بندی برنامه‌ریزی واقع‌بینانه، بافر زمانی
#
#
# ناسازگاری سیستم‌ها استانداردسازی
#
#
# نقض حریم خصوصی ناشناس‌سازی، رمزنگاری، کنترل دسترسی
# __________________________________________________________________________________________________________
#
# سوال 67
# یک جدول Project Plan تهیه کنید.
#
# . بخش business Understanding:
#
#
# فعالیت: مصاحبه و تعریف اهداف.
#
#
# زمان: ۲ هفته
#
#
# مسئول: تحلیل گر کسب و کار
#
#
#
#
#
#
# . بخش data Understanding:
#
#
# فعالیت: شناسایی داده
#
#
# زمان: ۲ هفته
#
#
# مسئول: مهندس داده.
#
#
#
#
#
#
# . بخش data preparation:
#
#
# فعالیت: اماده سازی داده ها و پاک سازی
# زمان: ۳ هفته
#
#
# مسئول: مهندس داده.
#
#
#
#
#
#
# . بخش Modeling :
#
#
# فعالیت: آموزش مدل
#
#
# زمان: ۳ هفته
#
#
# مسئول: data science
#
#
#
#
# . بخش evaluation :
#
#
# فعالیت: ارزیابی فنی و بالینی
#
#
# زمان: ۲ هفته
#
#
# مسئول: تیم پروژه.
#
#
#
#
# . بخش deployment:
#
#
# فعالیت: پیاده سازی مدل
#
#
# زمان: ۲ هفته
#
#
# مسئول: مهندس استقرار.
# __________________________________________________________________________________________________________
#
# سوال 68
# مهم‌ترین Milestone های پروژه را مشخص کنید.
#
# 1. تأیید اهداف کسب‌وکار
# 2. تکمیل شناخت داده‌ها
# 3. آماده شدن دیتاست نهایی
# 4. آموزش اولین مدل
# 5. تأیید ارزیابی فنی و بالینی
# 6. استقرار سیستم در محیط واقعی
# 7. آموزش و تحویل نهایی
# __________________________________________________________________________________________________________
#
# سوال 69
# چه عواملی ممکن است باعث شکست پروژه شوند؟
#
# · نبود داده کافی یا باکیفیت
#
#
# · عدم حمایت مدیریت
#
#
# · مقاومت پزشکان
#
#
# · کمبود بودجه
#
#
# · نبود نیروی متخصص
#
#
# · تغییر اهداف سازمان
#
#
# · نقض حریم خصوصی
#
#
# · عدم تعمیم‌پذیری مدل
#
#
# · تأخیر در زمان‌بندی
#
#
# · ضعف در ارتباطات تیمی
# __________________________________________________________________________________________________________
#
# سوال 70
# یک Executive Summary برای مدیرعامل بیمارستان بنویسید.
#
# این پروژه با هدف شناسایی بیماران پرریسک قلبی قبل از انجام آزمایش‌های تخصصی تعریف شده است. با توجه به افزایش تعداد بیماران و محدودیت تجهیزات، انجام آزمایش برای همه بیماران هزینه‌بر و زمان‌بر است. هدف این پروژه، ساخت یک سیستم هوشمند مبتنی بر داده‌کاوی است که با دقت بالا بیماران پرریسک را شناسایی کند تا منابع محدود بیمارستان به صورت بهینه تخصیص یابد.
#
# انتظار می‌رود این پروژه منجر به کاهش هزینه‌ها، کاهش زمان انتظار، بهبود کیفیت درمان و افزایش رضایت بیماران و پزشکان شود. موفقیت پروژه با معیارهایی مثل Recall بالای ۹۰٪، پذیرش پزشکان و کاهش هزینه‌ها سنجیده خواهد شد.

# %% [markdown]
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
# __________________________________________________________________________________________________________
#
# گزارش نهایی
#
# مسئله اصلی کسب‌وکار چیست؟
#
# مرکز تخصصی قلب با افزایش تعداد بیماران مواجه است انجام آزمایشات تخصصی قلب برای تمامی بیماران زمان بر ، هزینه بر و وابسته به تجهیزات است. بیمارستان نمی‌تواند برای همه بیماران به یک اندازه آزمایش انجام‌دهد و نیاز دارد قبل از انجام ازمایش بیماران پر ریسک تر را شناسایی کند تا آزمایشات تخصصی تری روی ان ها انجام دهد.
#
# __________________________________________________________________________________________________________
#
# هدف داده‌کاوی چیست؟
#
# هدف داده کاوی ساخت مدل طبقه‌ بندی دو دویی است که با استفاده از داده های بالینی بیماران احتمال ابتلا به بیماری قلبی را پیش بینی کند و بیماران را به دو دسته پر ریسک و کم ریسک طبقه بندی کند و مدل باید دقت بالایی در شناسایی داشته باشد.
# __________________________________________________________________________________________________________
#
# چرا این پروژه ارزش انجام دارد؟
#
# مالی: کاهش هزینه های درمانی و آزمایشات غیر ضروری.
# پزشکی : تشخیص زود هنگام بیماران پر ریسک ، کاهش مرگ و میر
# عملیاتی: کاهش زمان انتظار بیماران
# رضایت: افزایش رضایت بیماران و پزشکان از فرایند درمان.
#
# بدون این پروژه بیمارستان با افزایش هزینه، اتلاف منابع و تاخیر در تشخیص بیماران روبه رو است.
# __________________________________________________________________________________________________________
#
# مهم‌ترین ریسک‌های پروژه چیست؟
#
# ناقص یا ناکافی بودن اطلاعات
# کیفت پایین داده ها
# کمبود بودجه
# تغییر نیاز یا اهداف سازمان
# نبود نیروی متخصص
# ناسازگاری سیستم ها و تجهیزات
# تاخیر در زمان پروژه
# __________________________________________________________________________________________________________
#
# معیار موفقیت پروژه چیست؟
#
# فنی:
# بالای ۹۰ درصد recall برای پر ریسک ها
# قابل قبول بودن f1_score
# کسب و کار:
# کاهش تعداد آزمایشات تخصصی غیر ضروری
# کاهش هزینه بیمارستان
# کاهش زمان انتظار بیماران
# پذیرش توسط پزشکان
# رضایت بیماران
# __________________________________________________________________________________________________________
#
# برنامه اجرای پروژه چگونه خواهد بود؟
#
#
# پروژه در قالب شش فاز crisp_dm اجرا میشود:
#
#
# ۱.درک کسب و کار
#
#
# زمان: دو هفته
#
#
# سند اهداف،ذی نفعان و ریسک ها.
#
#
#
#
#
# ۲. درک داده:
#
#
# زمان: دوهفته
#
#
# گزارش داده و شناخت ان.
#
#
#
#
# ۳. اماده سازی داده:
#
#
# زمان: ۳ هفته
#
#
# دیتاست تمیز و اماده مدل سازی
#
#
#
#
#
# ۴. مدل سازی:
#
#
# زمان: ۳ هفته
#
#
# آموزش دیده و ارزیابی شده است.
#
#
#
#
#
# ۵. استقرار:
#
#
# زمان:  دو هفته
#
#
# استقرار سیستم در محیط
#
#
#
#
#
# ۶. اموزش و تحویل:
#
#
# زمان:۱ هفته
#
#
# مستندات و آموزش کاربران.
